# %% [markdown]
# # Make survey figures

# %%
# Add project root to path
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parents[1]
sys.path.append(str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)

# %%
from src.survey.figure2 import make_figure2
from src.survey.figure3a import make_figure3a
from src.survey.figure3b import make_figure3b
from src.survey.figure_s1 import make_figure_s1

# %%
# Generate survey figures
fig2, _ = make_figure2(save_png=True)
fig3a = make_figure3a(save_png=True)
fig3b = make_figure3b(save_png=True)
fig_s1 = make_figure_s1(save_png=True)

# %%
import matplotlib.pyplot as plt
plt.show()
